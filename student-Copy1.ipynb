# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd
import numpy as np
import requests
import re
import bleach
from time import sleep
from random import randint
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
names = []
years = []
imdb_ratings = []
ratings = []
runtimes = []
genres = []
for i in range(1, 10252, 50):
    url = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=5000,&languages=en&sort=boxoffice_gross_us,desc&start={}&explore=genres&ref_=adv_nxt'.format(i)
    response = requests.get(url)
    sleep(randint(8,15))
    html_soup = BeautifulSoup(response.text, 'html.parser')
    movie_containers = html_soup.find_all('div', class_='lister-item mode-advanced')
# Extract data from individual movie container
    for container in movie_containers:
# If the movie has Rating, then extract:
        if container.find('span', class_ = 'certificate') is not None:
# The name
            name = container.h3.a.text
            names.append(name)
# The year
            year = container.h3.find('span', class_ = 'lister-item-year').text
            years.append(year)
# The IMDB rating
            imdb = float(container.strong.text)
            imdb_ratings.append(imdb)
# The Rating
            rating = container.find('span', class_ = 'certificate').text
            ratings.append(rating)
# The number of votes
            runtime = container.find('span', class_ = 'runtime').text
            runtimes.append(runtime)
# The Movie Genres
            genre = container.find('span', class_ = 'genre').text
            genres.append(genre)

# %%
IMDb_df = pd.DataFrame({'Movie': names,
'Year': years,
'IMDb': imdb_ratings,
'Rating': ratings,
'Runtime': runtimes,
'Genre': genres
})

# %%
IMDb_df['Year'] = IMDb_df['Year'].str[-5:-1].astype(int)

# %%
IMDb_df['Runtime'] = IMDb_df['Runtime'].str[:-4].astype(int)

# %%
IMDb_df['Genre'] = IMDb_df['Genre'].map(lambda x: x.strip())

# %%
print(IMDb_df.info())
IMDb_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10135 entries, 0 to 10134
# Data columns (total 6 columns):
# Movie      10135 non-null object
# Year       10135 non-null int64
# IMDb       10135 non-null float64
# Rating     10135 non-null object
# Runtime    10135 non-null int64
# Genre      10135 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 475.2+ KB
# None
#                                             Movie  Year  IMDb Rating  Runtime  \
# 0      Star Wars: Episode VII - The Force Awakens  2015   7.9  PG-13      138
# 1                               Avengers: Endgame  2019   8.4  PG-13      181
# 2                                          Avatar  2009   7.8  PG-13      162
# 3                                   Black Panther  2018   7.3  PG-13      134
# 4                          Avengers: Infinity War  2018   8.4  PG-13      149
# ...                                           ...   ...   ...    ...      ...
# 10130                     The Secret Life of Pets  2016   6.5     PG       87
# 10131                             Despicable Me 2  2013   7.3     PG       98
# 10132                             The Jungle Book  2016   7.4     PG      106
# 10133                                    Deadpool  2016   8.0      R      108
# 10134                                  Inside Out  2015   8.1     PG       95
#
#                               Genre
# 0         Action, Adventure, Sci-Fi
# 1          Action, Adventure, Drama
# 2        Action, Adventure, Fantasy
# 3         Action, Adventure, Sci-Fi
# 4         Action, Adventure, Sci-Fi
# ...                             ...
# 10130  Animation, Adventure, Comedy
# 10131  Animation, Adventure, Comedy
# 10132      Adventure, Drama, Family
# 10133     Action, Adventure, Comedy
# 10134  Animation, Adventure, Comedy
#
# [10135 rows x 6 columns]

# %%
a_names = []
a_release = []
actors = []
directors = []
for i in range(1, 10252, 50):
    url = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=5000,&languages=en&sort=boxoffice_gross_us,desc&start={}&explore=genres&ref_=adv_nxt'.format(i)
    response = requests.get(url)
    sleep(randint(8,15))
    html_soup = BeautifulSoup(response.text, 'lxml')
    movie_containers = html_soup.find_all('div', class_='lister-item mode-advanced')
    for container in movie_containers:
        a_name = container.h3.a.text
        a_names.append(a_name)
        
        year = container.h3.find('span', class_ = 'lister-item-year').text
        a_release.append(year)
    
        imdb_names_cont = container.find('p', class_ = '')
        b = imdb_names_cont.find_all('a')
        actors.append(b[-4:])
        directors.append(b[-5::-1])

# %%
clean_actors = []
clean_directors = []
def people_clean(table, new):
    for p in table:
        clean = bleach.clean(p, tags=[], strip=True)
        new.append(clean)

# %%
people_clean(actors, clean_actors)
people_clean(directors, clean_directors)

# %%
people_df = pd.DataFrame({
'Movie': a_names,
'Actors': clean_actors,
'Directors': clean_directors,
})
print(people_df.info())
people_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10300 entries, 0 to 10299
# Data columns (total 3 columns):
# Movie        10300 non-null object
# Actors       10300 non-null object
# Directors    10300 non-null object
# dtypes: object(3)
# memory usage: 241.5+ KB
# None
#                                             Movie  \
# 0      Star Wars: Episode VII - The Force Awakens
# 1                               Avengers: Endgame
# 2                                          Avatar
# 3                                   Black Panther
# 4                          Avengers: Infinity War
# ...                                           ...
# 10295                     The Secret Life of Pets
# 10296                             Despicable Me 2
# 10297                             The Jungle Book
# 10298                                    Deadpool
# 10299                                  Inside Out
#
#                                                   Actors  \
# 0      [Daisy Ridley, John Boyega, Oscar Isaac, Domhn...
# 1      [Robert Downey Jr., Chris Evans, Mark Ruffalo,...
# 2      [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 3      [Chadwick Boseman, Michael B. Jordan, Lupita N...
# 4      [Robert Downey Jr., Chris Hemsworth, Mark Ruff...
# ...                                                  ...
# 10295  [Louis C.K., Eric Stonestreet, Kevin Hart, Lak...
# 10296  [Steve Carell, Kristen Wiig, Benjamin Bratt, M...
# 10297  [Neel Sethi, Bill Murray, Ben Kingsley, Idris ...
# 10298  [Ryan Reynolds, Morena Baccarin, T.J. Miller, ...
# 10299  [Amy Poehler, Bill Hader, Lewis Black, Mindy K...
#
#                               Directors
# 0                         [J.J. Abrams]
# 1            [Joe Russo, Anthony Russo]
# 2                       [James Cameron]
# 3                        [Ryan Coogler]
# 4            [Joe Russo, Anthony Russo]
# ...                                 ...
# 10295     [Yarrow Cheney, Chris Renaud]
# 10296     [Chris Renaud, Pierre Coffin]
# 10297                     [Jon Favreau]
# 10298                      [Tim Miller]
# 10299  [Ronnie Del Carmen, Pete Docter]
#
# [10300 rows x 3 columns]

# %%
actors_df = pd.DataFrame({
'Movie': a_names,
'Year': a_release,
'Actors': actors})

# %%
actors_df1 = actors_df['Actors'].apply(pd.Series)
actors_df2 = pd.merge(actors_df, actors_df1, right_index = True, left_index = True)
actors_df2 = actors_df2.drop(['Actors'], axis = 1)
final_actors_df = actors_df2.melt(id_vars = ['Movie', 'Year'], var_name = ['Actors'])
final_actors_df = final_actors_df.drop('Actors', axis=1)
final_actors_df = final_actors_df.drop_duplicates()

# %%
final_actors_df['Year'] = final_actors_df['Year'].str[-5:-1].astype(int)

# %%
final_actors_df['value'] = final_actors_df['value'].apply(lambda x: re.sub('<[^<]+?>', '', str(x)))

# %%
final_actors_df['value']
# Out:
# 0             Daisy Ridley
# 1        Robert Downey Jr.
# 2          Sam Worthington
# 3         Chadwick Boseman
# 4        Robert Downey Jr.
#                ...
# 40895      Queenie Leonard
# 40896         Ralph Meeker
# 40897       Charles Coburn
# 40898           Alfie Bass
# 40899        Neville Brand
# Name: value, Length: 39996, dtype: object

# %%
print(final_actors_df.info())
final_actors_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39996 entries, 0 to 40899
# Data columns (total 3 columns):
# Movie    39996 non-null object
# Year     39996 non-null int64
# value    39996 non-null object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ MB
# None
#                                             Movie  Year              value
# 0      Star Wars: Episode VII - The Force Awakens  2015       Daisy Ridley
# 1                               Avengers: Endgame  2019  Robert Downey Jr.
# 2                                          Avatar  2009    Sam Worthington
# 3                                   Black Panther  2018   Chadwick Boseman
# 4                          Avengers: Infinity War  2018  Robert Downey Jr.
# ...                                           ...   ...                ...
# 40895                           The Narrow Margin  1952    Queenie Leonard
# 40896                              The Naked Spur  1953       Ralph Meeker
# 40897                             Monkey Business  1952     Charles Coburn
# 40898                       The Lavender Hill Mob  1951         Alfie Bass
# 40899                    Kansas City Confidential  1952      Neville Brand
#
# [39996 rows x 3 columns]

# %%
directors_df = pd.DataFrame({
'Movie': a_names,
'Year': a_release,
'Directors': directors})

# %%
directors_df1 = directors_df['Directors'].apply(pd.Series)
directors_df2 = pd.merge(directors_df, directors_df1, right_index = True, left_index = True)
directors_df2 = directors_df2.drop(['Directors'], axis = 1)
final_directors_df = directors_df2.melt(id_vars = ['Movie', 'Year'], var_name = ['Directors'])
final_directors_df = final_directors_df.drop('Directors', axis=1)
final_directors_df = final_directors_df.drop_duplicates()

# %%
final_directors_df['Year'] = final_directors_df['Year'].str[-5:-1].astype(int)

# %%
final_directors_df['value'] = final_directors_df['value'].apply(lambda x: re.sub('<[^<]+?>', '', str(x)))

# %%
final_directors_df = final_directors_df.drop_duplicates()
final_directors_df
# Out:
#                                              Movie  Year              value
# 0       Star Wars: Episode VII - The Force Awakens  2015        J.J. Abrams
# 1                                Avengers: Endgame  2019          Joe Russo
# 2                                           Avatar  2009      James Cameron
# 3                                    Black Panther  2018       Ryan Coogler
# 4                           Avengers: Infinity War  2018          Joe Russo
# ...                                            ...   ...                ...
# 285562                           The ABCs of Death  2012                nan
# 285694                             ABCs of Death 2  2014  Alejandro Brugués
# 295994                             ABCs of Death 2  2014    Robert Boocheck
# 306294                             ABCs of Death 2  2014     Julian Barratt
# 316594                             ABCs of Death 2  2014      Rodney Ascher
#
# [20955 rows x 3 columns]

# %%
final_budget_container = []
for x in range(1, 6002, 100):
    url2 = 'https://www.the-numbers.com/movie/budgets/all/{}'.format(x)
    response2 = requests.get(url2)
    sleep(randint(8,15))
    soup = BeautifulSoup(response2.text, 'html.parser')
    budget_containers = soup.find_all('td')
    for containers in budget_containers:
        final_budget_container.append(containers)

# %%
date_release = final_budget_container[1::3][::2]
movie_title = final_budget_container[2::3][::2]
production_budget = final_budget_container[3::3][::2]
domestic_gross = final_budget_container[4::3][::2]
worldwide_gross = final_budget_container[5::3][::2]

# %%
final_date = []
final_movie = []
final_budget = []
final_domestic = []
final_worldwide = []
def budget_clean(table, new):
    for p in table:
        clean = bleach.clean(p, tags=[], strip=True)
        new.append(clean)

# %%
budget_clean(date_release, final_date)
budget_clean(movie_title, final_movie)
budget_clean(production_budget, final_budget)
budget_clean(domestic_gross, final_domestic)
budget_clean(worldwide_gross, final_worldwide)

# %%
budget_df = pd.DataFrame({'Release Date': final_date,
'Movie': final_movie,
'Production Budget': final_budget,
'Domestic Gross': final_domestic,
'Worldwide Gross': final_worldwide,
})
print(budget_df.info())
budget_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6043 entries, 0 to 6042
# Data columns (total 5 columns):
# Release Date         6043 non-null object
# Movie                6043 non-null object
# Production Budget    6043 non-null object
# Domestic Gross       6043 non-null object
# Worldwide Gross      6043 non-null object
# dtypes: object(5)
# memory usage: 236.2+ KB
# None
#       Release Date                                        Movie  \
# 0     Apr 23, 2019                            Avengers: Endgame
# 1     May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2     Apr 22, 2015                      Avengers: Age of Ultron
# 3     Dec 16, 2015         Star Wars Ep. VII: The Force Awakens
# 4     Apr 25, 2018                       Avengers: Infinity War
# ...            ...                                          ...
# 6038       Unknown                                       Red 11
# 6039   Apr 2, 1999                                    Following
# 6040  Jul 13, 2005                Return to the Land of Wonders
# 6041  Sep 29, 2015                         A Plague So Pleasant
# 6042   Aug 5, 2005                            My Date With Drew
#
#      Production Budget Domestic Gross  Worldwide Gross
# 0         $400,000,000   $858,373,000   $2,797,800,564
# 1         $379,000,000   $241,063,875   $1,045,663,875
# 2         $365,000,000   $459,005,868   $1,396,099,202
# 3         $306,000,000   $936,662,225   $2,065,478,084
# 4         $300,000,000   $678,815,482   $2,048,359,754
# ...                ...            ...              ...
# 6038            $7,000             $0               $0
# 6039            $6,000        $48,482         $240,495
# 6040            $5,000         $1,338           $1,338
# 6041            $1,400             $0               $0
# 6042            $1,100       $181,041         $181,041
#
# [6043 rows x 5 columns]

# %%
budget_df['Production Budget'] = budget_df['Production Budget'].str.replace(',','').str.replace('$','').astype(int)
budget_df['Domestic Gross'] = budget_df['Domestic Gross'].str.replace(',','').str.replace('$','').astype(int)
budget_df['Worldwide Gross'] = budget_df['Worldwide Gross'].str.replace(',','').str.replace('$','').astype(int)

# %%
budget_df['Year'] = budget_df['Release Date'].str[-4:]

# %%
budget_df = budget_df[budget_df['Year'] != 'nown']

# %%
budget_df['Year'] = budget_df['Year'].astype(int)
# Out:
# /Users/derekdavis/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
IMDb_budget = pd.merge(IMDb_df, budget_df)

# %%
IMDb_budget.nunique()
# Out:
# Movie                3770
# Year                   85
# IMDb                   74
# Rating                 13
# Runtime               138
# Genre                 310
# Release Date         2241
# Production Budget     379
# Domestic Gross       3712
# Worldwide Gross      3765
# dtype: int64

# %%
IMDb_budget = IMDb_budget.drop_duplicates()

# %%
print(IMDb_budget.info())
IMDb_budget
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3828 entries, 0 to 4061
# Data columns (total 10 columns):
# Movie                3828 non-null object
# Year                 3828 non-null int64
# IMDb                 3828 non-null float64
# Rating               3828 non-null object
# Runtime              3828 non-null int64
# Genre                3828 non-null object
# Release Date         3828 non-null object
# Production Budget    3828 non-null int64
# Domestic Gross       3828 non-null int64
# Worldwide Gross      3828 non-null int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 329.0+ KB
# None
#                             Movie  Year  IMDb     Rating  Runtime  \
# 0               Avengers: Endgame  2019   8.4      PG-13      181
# 7                          Avatar  2009   7.8      PG-13      162
# 14                  Black Panther  2018   7.3      PG-13      134
# 21         Avengers: Infinity War  2018   8.4      PG-13      149
# 28                        Titanic  1997   7.8      PG-13      194
# ...                           ...   ...   ...        ...      ...
# 4057  The Brain That Wouldn't Die  1962   4.5   Approved       82
# 4058                The Wrong Man  1956   7.4  Not Rated      105
# 4059                     Carousel  1956   6.6   Approved      128
# 4060       The Trouble with Harry  1955   7.1         PG       99
# 4061                      Niagara  1953   7.0  Not Rated       92
#
#                            Genre  Release Date  Production Budget  \
# 0       Action, Adventure, Drama  Apr 23, 2019          400000000
# 7     Action, Adventure, Fantasy  Dec 17, 2009          237000000
# 14     Action, Adventure, Sci-Fi  Feb 13, 2018          200000000
# 21     Action, Adventure, Sci-Fi  Apr 25, 2018          300000000
# 28                Drama, Romance  Dec 18, 1997          200000000
# ...                          ...           ...                ...
# 4057              Horror, Sci-Fi  Aug 10, 1962              60000
# 4058            Drama, Film-Noir  Dec 23, 1956            1200000
# 4059     Drama, Fantasy, Musical  Feb 16, 1956            3380000
# 4060             Comedy, Mystery   Oct 3, 1955            1200000
# 4061         Film-Noir, Thriller  Jan 21, 1953            1250000
#
#       Domestic Gross  Worldwide Gross
# 0          858373000       2797800564
# 7          760507625       2788701337
# 14         700059566       1346103376
# 21         678815482       2048359754
# 28         659363944       2208208395
# ...              ...              ...
# 4057               0                0
# 4058         2000000          2000000
# 4059               0             3604
# 4060         7000000          7000000
# 4061         2500000          2500000
#
# [3828 rows x 10 columns]

# %%
actors_finance = pd.merge(final_actors_df, budget_df)

# %%
actors_finance = actors_finance.drop_duplicates()

# %%
print(actors_finance.info())
actors_finance
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15320 entries, 0 to 15319
# Data columns (total 7 columns):
# Movie                15320 non-null object
# Year                 15320 non-null int64
# value                15320 non-null object
# Release Date         15320 non-null object
# Production Budget    15320 non-null int64
# Domestic Gross       15320 non-null int64
# Worldwide Gross      15320 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 957.5+ KB
# None
#                         Movie  Year              value  Release Date  \
# 0           Avengers: Endgame  2019  Robert Downey Jr.  Apr 23, 2019
# 1           Avengers: Endgame  2019        Chris Evans  Apr 23, 2019
# 2           Avengers: Endgame  2019       Mark Ruffalo  Apr 23, 2019
# 3           Avengers: Endgame  2019    Chris Hemsworth  Apr 23, 2019
# 4                      Avatar  2009    Sam Worthington  Dec 17, 2009
# ...                       ...   ...                ...           ...
# 15315  The Trouble with Harry  1955    Mildred Natwick   Oct 3, 1955
# 15316                 Niagara  1953     Marilyn Monroe  Jan 21, 1953
# 15317                 Niagara  1953      Joseph Cotten  Jan 21, 1953
# 15318                 Niagara  1953        Jean Peters  Jan 21, 1953
# 15319                 Niagara  1953      Max Showalter  Jan 21, 1953
#
#        Production Budget  Domestic Gross  Worldwide Gross
# 0              400000000       858373000       2797800564
# 1              400000000       858373000       2797800564
# 2              400000000       858373000       2797800564
# 3              400000000       858373000       2797800564
# 4              237000000       760507625       2788701337
# ...                  ...             ...              ...
# 15315            1200000         7000000          7000000
# 15316            1250000         2500000          2500000
# 15317            1250000         2500000          2500000
# 15318            1250000         2500000          2500000
# 15319            1250000         2500000          2500000
#
# [15320 rows x 7 columns]

# %%
directors_finance = pd.merge(final_directors_df, budget_df)

# %%
directors_finance = directors_finance.drop_duplicates()

# %%
directors_finance = directors_finance[directors_finance['value'] != 'nan']

# %%
print(directors_finance.info())
directors_finance
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4181 entries, 0 to 8009
# Data columns (total 7 columns):
# Movie                4181 non-null object
# Year                 4181 non-null int64
# value                4181 non-null object
# Release Date         4181 non-null object
# Production Budget    4181 non-null int64
# Domestic Gross       4181 non-null int64
# Worldwide Gross      4181 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 261.3+ KB
# None
#                             Movie  Year             value  Release Date  \
# 0               Avengers: Endgame  2019         Joe Russo  Apr 23, 2019
# 1               Avengers: Endgame  2019     Anthony Russo  Apr 23, 2019
# 3                          Avatar  2009     James Cameron  Dec 17, 2009
# 5                   Black Panther  2018      Ryan Coogler  Feb 13, 2018
# 7          Avengers: Infinity War  2018         Joe Russo  Apr 25, 2018
# ...                           ...   ...               ...           ...
# 8001  The Brain That Wouldn't Die  1962      Joseph Green  Aug 10, 1962
# 8003                The Wrong Man  1956  Alfred Hitchcock  Dec 23, 1956
# 8005                     Carousel  1956        Henry King  Feb 16, 1956
# 8007       The Trouble with Harry  1955  Alfred Hitchcock   Oct 3, 1955
# 8009                      Niagara  1953    Henry Hathaway  Jan 21, 1953
#
#       Production Budget  Domestic Gross  Worldwide Gross
# 0             400000000       858373000       2797800564
# 1             400000000       858373000       2797800564
# 3             237000000       760507625       2788701337
# 5             200000000       700059566       1346103376
# 7             300000000       678815482       2048359754
# ...                 ...             ...              ...
# 8001              60000               0                0
# 8003            1200000         2000000          2000000
# 8005            3380000               0             3604
# 8007            1200000         7000000          7000000
# 8009            1250000         2500000          2500000
#
# [4181 rows x 7 columns]

# %%
IMDb_budget.to_csv('IMDb_budgets.csv',  index=False)

# %%
IMDb_df.to_csv('IMDb_base.csv', index=False)

# %%
actors_finance.to_csv('Actors_Table.csv', index=False)

# %%
directors_finance.to_csv('Directors_Table.csv', index=False)
